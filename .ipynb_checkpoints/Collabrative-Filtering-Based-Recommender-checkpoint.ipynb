# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv')
books.head()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5136\4074757836.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
ratings = pd.read_csv('Ratings.csv')
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
users = pd.read_csv('Users.csv')
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %% [markdown]
# **obserations** : There are some null value in the dataset

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %% [markdown]
# **observations** - age column has 110762 null values

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %% [markdown]
# **observation** - no null values here ... great

# %%
books.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **observations** - NO duplicated values in all three data

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books['Book-Author'].value_counts().head(10).plot(kind = 'bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# **Observations :** - Top 10 most frequent authors in the dataset

# %%
books['Book-Title'].value_counts().head(10)
# Out:
# Selected Poems                    27
# Little Women                      24
# Wuthering Heights                 21
# The Secret Garden                 20
# Dracula                           20
# Adventures of Huckleberry Finn    20
# Jane Eyre                         19
# The Night Before Christmas        18
# Pride and Prejudice               18
# Great Expectations                17
# Name: Book-Title, dtype: int64

# %% [markdown]
# **Observatoion :** - Here some books have multiple publications and ISBN value , hence they repeat.

# %%
books['Year-Of-Publication'].value_counts().head(10)
# Out:
# 2002    13903
# 2001    13715
# 1999    13414
# 2000    13373
# 1998    12116
# 2003    11610
# 1997    11494
# 1996    10687
# 1995    10259
# 1994     8857
# Name: Year-Of-Publication, dtype: int64

# %%
books.describe()
# Out:
#               ISBN      Book-Title      Book-Author  Year-Of-Publication  \
# count       271360          271360           271359               271360
# unique      271360          242135           102023                  202
# top     0195153448  Selected Poems  Agatha Christie                 2002
# freq             1              27              632                13903
#
#         Publisher                                        Image-URL-S  \
# count      271358                                             271360
# unique      16807                                             271044
# top     Harlequin  http://images.amazon.com/images/P/185326119X.0...
# freq         7535                                                  2
#
#                                               Image-URL-M  \
# count                                              271360
# unique                                             271044
# top     http://images.amazon.com/images/P/185326119X.0...
# freq                                                    2
#
#                                               Image-URL-L
# count                                              271357
# unique                                             271041
# top     http://images.amazon.com/images/P/225307649X.0...
# freq                                                    2

# %%
books['Publisher'].value_counts().head().plot(kind = 'pie')
plt.show()

# %% [markdown]
# Here Harlequin is the biggest publisher of all, over the years.

# %% [markdown]
# ### Popularity based Recommendation System

# %%
books_with_rating = books.merge(ratings, on = 'ISBN')
books_with_rating.head()
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
# 1    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 2    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 3    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
# 4    HarperFlamingo Canada  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0002005018.0...
# 3  http://images.amazon.com/images/P/0002005018.0...
# 4  http://images.amazon.com/images/P/0002005018.0...
#
#                                          Image-URL-L  User-ID  Book-Rating
# 0  http://images.amazon.com/images/P/0195153448.0...        2            0
# 1  http://images.amazon.com/images/P/0002005018.0...        8            5
# 2  http://images.amazon.com/images/P/0002005018.0...    11400            0
# 3  http://images.amazon.com/images/P/0002005018.0...    11676            8
# 4  http://images.amazon.com/images/P/0002005018.0...    41385            0

# %%
num_rating_df = books_with_rating.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns = {'Book-Rating' : 'num-rating'}, inplace = True)
num_rating_df.head()
# Out:
#                                           Book-Title  num-rating
# 0   A Light in the Storm: The Civil War Diary of ...           4
# 1                              Always Have Popsicles           1
# 2               Apple Magic (The Collector's series)           1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4   Beyond IBM: Leadership Marketing and Finance ...           1

# %%
avg_rating_df = books_with_rating.groupby('Book-Title').mean()['Book-Rating'].reset_index()
avg_rating_df.rename(columns = {'Book-Rating' : 'avg-rating'}, inplace = True)
avg_rating_df.head()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_5136\3375340489.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_rating_df = books_with_rating.groupby('Book-Title').mean()['Book-Rating'].reset_index()
#                                           Book-Title  avg-rating
# 0   A Light in the Storm: The Civil War Diary of ...        2.25
# 1                              Always Have Popsicles        0.00
# 2               Apple Magic (The Collector's series)        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...        0.00

# %%
popularity_df = num_rating_df.merge(avg_rating_df, on = 'Book-Title')
popularity_df.head()
# Out:
#                                           Book-Title  num-rating  avg-rating
# 0   A Light in the Storm: The Civil War Diary of ...           4        2.25
# 1                              Always Have Popsicles           1        0.00
# 2               Apple Magic (The Collector's series)           1        0.00
# 3   Ask Lily (Young Women of Faith: Lily Series, ...           1        8.00
# 4   Beyond IBM: Leadership Marketing and Finance ...           1        0.00

# %% [markdown]
# <b><br><br>We only want those books whose number of ratings is greater than 250:</b>

# %%
popularity_df = popularity_df[popularity_df['num-rating']>= 250].sort_values('avg-rating', ascending = False).head(50)
popularity_df.reset_index()
# Out:
#      index                                         Book-Title  num-rating  \
# 0    80434  Harry Potter and the Prisoner of Azkaban (Book 3)         428
# 1    80422       Harry Potter and the Goblet of Fire (Book 4)         387
# 2    80441     Harry Potter and the Sorcerer's Stone (Book 1)         278
# 3    80426  Harry Potter and the Order of the Phoenix (Boo...         347
# 4    80414   Harry Potter and the Chamber of Secrets (Book 2)         556
# 5   191612  The Hobbit : The Enchanting Prelude to The Lor...         281
# 6   187377  The Fellowship of the Ring (The Lord of the Ri...         368
# 7    80445  Harry Potter and the Sorcerer's Stone (Harry P...         575
# 8   211384     The Two Towers (The Lord of the Rings, Part 2)         260
# 9   219741                              To Kill a Mockingbird         510
# 10  183573                                  The Da Vinci Code         898
# 11  187880                 The Five People You Meet in Heaven         430
# 12  180556                             The Catcher in the Rye         449
# 13  196326                          The Lovely Bones: A Novel        1295
# 14     764                                               1984         284
# 15  144165                           Prodigal Summer: A Novel         253
# 16  128670                                         Neverwhere         265
# 17  206502                            The Secret Life of Bees         774
# 18  168719  Stupid White Men ...and Other Sorry Excuses fo...         283
# 19  223135  Tuesdays with Morrie: An Old Man, a Young Man,...         493
# 20  204387                The Red Tent (Bestselling Backlist)         723
# 21  191589               The Hitchhiker's Guide to the Galaxy         268
# 22  129379   Nickel and Dimed: On (Not) Getting By in America         335
# 23   93381                                      Into the Wild         252
# 24   63867                                     Fahrenheit 451         409
# 25   74750                          Girl with a Pearl Earring         526
# 26  136145                                          Outlander         283
# 27  233370  Where the Heart Is (Oprah's Book Club (Paperba...         585
# 28  156102                     Seabiscuit: An American Legend         275
# 29  107962                                         Life of Pi         664
# 30  176845                                     The Bean Trees         389
# 31    2281  A Child Called \It\": One Child's Courage to S...         265
# 32    8434                                     ANGELA'S ASHES         279
# 33   76343                                        Good in Bed         490
# 34   64931  Fast Food Nation: The Dark Side of the All-Ame...         321
# 35   12700                                      American Gods         302
# 36  161645                                 Skipping Christmas         322
# 37  105777  Left Behind: A Novel of the Earth's Last Days ...         318
# 38  189551    The Golden Compass (His Dark Materials, Book 1)         336
# 39  181679                                   The Color Purple         314
# 40  160336                               Silence of the Lambs         256
# 41    8752                                        About a Boy         262
# 42  158138                  Seven Up (A Stephanie Plum Novel)         278
# 43  175097  The Alchemist: A Fable About Following Your Dream         266
# 44   80069  Hard Eight : A Stephanie Plum Novel (A Stephan...         269
# 45  170101                       Suzanne's Diary for Nicholas         457
# 46  111073                                  Lord of the Flies         259
# 47    5664                            A Prayer for Owen Meany         413
# 48  212070   The Vampire Lestat (Vampire Chronicles, Book II)         301
# 49  233851       White Oleander : A Novel (Oprah's Book Club)         356
#
#     avg-rating
# 0     5.852804
# 1     5.824289
# 2     5.737410
# 3     5.501441
# 4     5.183453
# 5     5.007117
# 6     4.948370
# 7     4.895652
# 8     4.880769
# 9     4.700000
# 10    4.642539
# 11    4.551163
# 12    4.545657
# 13    4.468726
# 14    4.454225
# 15    4.450593
# 16    4.449057
# 17    4.447028
# 18    4.356890
# 19    4.354970
# 20    4.334716
# 21    4.328358
# 22    4.289552
# 23    4.273810
# 24    4.264059
# 25    4.218631
# 26    4.173145
# 27    4.105983
# 28    4.098182
# 29    4.088855
# 30    4.087404
# 31    4.086792
# 32    4.075269
# 33    4.055102
# 34    4.037383
# 35    4.006623
# 36    4.006211
# 37    4.003145
# 38    4.000000
# 39    3.964968
# 40    3.960938
# 41    3.900763
# 42    3.888489
# 43    3.875940
# 44    3.825279
# 45    3.820569
# 46    3.818533
# 47    3.796610
# 48    3.777409
# 49    3.772472

# %% [markdown]
# **Observation** - These are the top 50 most popular books on our platform

# %% [markdown]
# Now I want book's author name , image of the book to show on the dashboard

# %%
popularity_df = popularity_df.merge(books, on = 'Book-Title').drop_duplicates('Book-Title')[['Book-Title', 'Book-Author',
                                                                             'Image-URL-M', 'num-rating', 'avg-rating',
                                                                             'Year-Of-Publication']]
popularity
